-1.42598382860000,
-1.41419444980000,
-1.41255600230000,
-1.43948088780000,
-1.42598382860000,
-1.43756957520000,
-1.40564764940000,
-1.42598382860000,
-1.44644133220000,
-1.42448103880000,
-1.43619841260000,
-1.42598382860000,
-1.42598382860000,
-1.43756957520000,
-1.42598382860000,
-1.44644133220000,
-1.43479890880000,
-1.45552020080000,
-1.45552020080000,
-1.43891324360000,
-1.45136740080000
])

UN5 = np.cos(phi5)
VN5 = np.sin(phi5)

# %%
plt.figure(figsize=(10,10))
plt.quiver(X5, Y5, UN5, VN5, 
           color='Cyan', 
           headlength=7)

plt.grid()
plt.title('Plot of robot poses after hard right commands')
plt.show(plot2)

# %%
plt.figure(figsize=(10,10))
plt.ylim([-450, 450])
plt.xlim([0,600])
plt.ylabel("Y coordinate (mm)")
plt.xlabel("X coordinate (mm)")
plt.title("Poses recorded from LeJOS robot")

straight_patch = mpatches.Patch(color='Teal', label='Going straight')
plt.quiver(X1, Y1, UN1, VN1, 
           color='Teal', 
           headlength=7)
slight_left_patch = mpatches.Patch(color='Red', label='Going slightly left')
plt.quiver(X2, Y2, UN2, VN2, 
           color='Red', 
           headlength=7)
slight_right_patch = mpatches.Patch(color='Blue', label='Going slightly right')
plt.quiver(X3, Y3, UN3, VN3, 
           color='Blue', 
           headlength=7)
left_patch = mpatches.Patch(color='Green', label='Going left')
plt.quiver(X4, Y4, UN4, VN4, 
           color='Green', 
           headlength=7)
right_patch = mpatches.Patch(color='Cyan', label='Going right')
plt.quiver(X5, Y5, UN5, VN5, 
           color='Cyan', 
           headlength=7)

plt.grid()
plt.legend(handles=[straight_patch, slight_left_patch, slight_right_patch, left_patch, right_patch])
plt.show()

# %%
import matplotlib.mlab as mlab
# the histogram of the data
mu=np.mean(X1)
sigma=np.std(X1)

print("mu = %f, sigma = %f" % (mu, sigma))

plt.figure(figsize=(10,10))
n, bins, patches = plt.hist(X1, 6, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ x\ for\ going\ straight}$')
plt.grid(True)

plt.show()

# %%
mu=np.mean(phi2)
sigma=np.std(phi2)

print("mu = %f, sigma = %f" % (mu, sigma))

plt.figure(figsize=(10,10))
n, bins, patches = plt.hist(phi2, 6, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ \phi\ for\ going\ slight left}$')
plt.grid(True)

plt.show()

# %%
mu=np.mean(phi3)
sigma=np.std(phi3)

print("mu = %f, sigma = %f" % (mu, sigma))

plt.figure(figsize=(10,10))
n, bins, patches = plt.hist(Y3, 6, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ y\ for\ going\ slight right}$')
plt.grid(True)

plt.show()

# %%
mu=np.mean(phi4)
sigma=np.std(phi4)

print("mu = %f, sigma = %f" % (mu, sigma))

plt.figure(figsize=(10,10))
n, bins, patches = plt.hist(phi4, 6, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ \phi\ for\ going\ left}$')
plt.grid(True)

plt.show()

# %%
mu=np.mean(X5)
sigma=np.std(X5)

print("mu = %f, sigma = %f" % (mu, sigma))

plt.figure(figsize=(10,10))
n, bins, patches = plt.hist(phi5, 6, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ \phi\ for\ going\ right}$')
plt.grid(True)

plt.show()
